# %%
from transformers import AutoImageProcessor, DetrForObjectDetection
import torch
from PIL import Image
import requests 
import json
import pandas as pd
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\JALAL\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
url = "./EMOTIC (1)/EMOTIC/PAMI/emotic/emodb_small/images/4m7t3bsqtw1upazkri.jpg"
url = url.replace("\\", "/")

image = Image.open(url)

# %%
image_processor = AutoImageProcessor.from_pretrained("facebook/detr-resnet-50")
model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")

inputs = image_processor(images=image, return_tensors="pt")
outputs = model(**inputs)

# convert outputs (bounding boxes and class logits) to Pascal VOC format (xmin, ymin, xmax, ymax)
target_sizes = torch.tensor([image.size[::-1]])
results = image_processor.post_process_object_detection(outputs, threshold=0.9, target_sizes=target_sizes)[0]


for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
    box = [round(i, 2) for i in box.tolist()]
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# c:\Users\JALAL\anaconda3\Lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import numpy as np

# Assuming you have already filtered 'person' labels and their corresponding boxes
person_scores = []
person_labels = []
person_boxes = []

for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
    if model.config.id2label[label.item()] == 'person':
        person_labels.append(label)
        person_boxes.append(box)
        person_scores.append(score.item())  # Store scores for sorting

# Now sort person_scores and use the sorted indices to sort person_labels and person_boxes
sorted_indices = np.argsort(person_scores)[::-1]  # [::-1] for descending order

sorted_person_labels = [person_labels[i] for i in sorted_indices]
sorted_person_boxes = [person_boxes[i] for i in sorted_indices]
sorted_person_scores = [person_scores[i] for i in sorted_indices]


sorted_results = {
    "scores": sorted_person_scores,
    "labels": sorted_person_labels,
    "boxes": sorted_person_boxes
}

bboxes = [[int(x) for x in bbox] for bbox in sorted_results["boxes"]]
bboxes[:5]
# Out:
# [[675, 430, 817, 920],
#  [999, 908, 1464, 1263],
#  [1659, 601, 1895, 1072],
#  [1009, 764, 1241, 1063],
#  [1211, 728, 1331, 922]]

# %%
def model_results(img):

    image_processor = AutoImageProcessor.from_pretrained("facebook/detr-resnet-50")
    model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")
    inputs = image_processor(images=img, return_tensors="pt")
    outputs = model(**inputs)

    results = image_processor.post_process_object_detection(outputs, threshold=0.9, target_sizes=torch.tensor([img.size[::-1]]))[0]

    person_scores = []
    person_labels = []
    person_boxes = []

    for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
        if model.config.id2label[label.item()] == 'person':
            person_labels.append(label)
            person_boxes.append(box)
            person_scores.append(score.item())  

    # Sorting the results by score
    sorted_indices = np.argsort(person_scores)[::-1]  

    sorted_person_labels = [person_labels[i] for i in sorted_indices]
    sorted_person_boxes = [person_boxes[i] for i in sorted_indices]
    sorted_person_scores = [person_scores[i] for i in sorted_indices]


    sorted_results = {
        "scores": sorted_person_scores,
        "labels": sorted_person_labels,
        "boxes": sorted_person_boxes
    }

    bboxes = [[int(x) for x in bbox] for bbox in sorted_results["boxes"]]
    bboxes = bboxes[:15]
    
    return bboxes

def iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1g, y1g, x2g, y2g = box2
    # determine the coordinates of the intersection rectangle
    xA = max(x1, x1g)
    yA = max(y1, y1g)
    xB = min(x2, x2g)
    yB = min(y2, y2g)
    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    # compute the area of both the prediction and ground-truth
    # rectangles
    boxAArea = (x2 - x1 + 1) * (y2 - y1 + 1)
    boxBArea = (x2g - x1g + 1) * (y2g - y1g + 1)
    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = interArea / float(boxAArea + boxBArea - interArea)
    # return the intersection over union value
    return iou

def get_iou(bbox1, bbox2, thresh, new_annots = []):
    iou_score = iou(bbox1, bbox2)
    if iou_score > thresh:
        new_annots.append(bbox1)
        #new_annots.append(bbox2)
    else:
        new_annots.append(bbox1)
        new_annots.append(bbox2)
    return new_annots

def remove_duplicates(lst):
    return [list(t) for t in {tuple(item) for item in lst}]

# %%
url = "EMOTIC (1)\EMOTIC\PAMI\emotic/mscoco/images/COCO_val2014_000000562243.jpg"
url = url.replace("\\", "/")

image = Image.open(url)

bboxes = model_results(image)
image_id = 562243
list_appair = []
new_bbox = []
list_appair.append({'id': image_id, 'bboxes': bboxes})

new_annotations = []
train_annots = [{"image_id": 0, "id": 0, "category_id": 1, "bbox": [83, 63, 564, 637], 
                 "coco_ids": {"image_id": 562243, "annotations_id": 448867}, 
                 "annotations_categories": ["Disconnection", "Doubt/Confusion"], 
                 "annotations_continuous": {"valence": 5, "arousal": 3, "dominance": 9}, 
                 "gender": "Male", "age": "Adult"}, 
                 {"image_id": 0, "id": 1, "category_id": 1, "bbox": [295, 347, 382, 639], 
                  "coco_ids": {"image_id": 562243, "annotations_id": 448867}, 
                  "annotations_categories": ["Disconnection", "Doubt/Confusion"], 
                  "annotations_continuous": {"valence": 5, "arousal": 3, "dominance": 9}, 
                  "gender": "Male", "age": "Adult"}, 
                  {"image_id": 0, "id": 2, "category_id": 1, "bbox": [86, 58, 564, 628], 
                   "coco_ids": {"image_id": 562243, "annotations_id": 448867}, 
                   "annotations_categories": ["Disconnection", "Doubt/Confusion"], 
                   "annotations_continuous": {"valence": 5, "arousal": 3, "dominance": 9}, 
                   "gender": "Male", "age": "Adult"}]

old_bbx = [[102, 33, 474, 737], [295, 347, 382, 639], [86, 58, 564, 628]]
print(bboxes)
print(old_bbx)
for single_bbox in old_bbx:
    for bbox2 in bboxes:
        get_iou(single_bbox, bbox2, 0.8, new_bbox)
#new_bbox = old_bbx + new_bbox
new_bbox = remove_duplicates(new_bbox)
print(new_bbox)
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [[83, 63, 564, 637]]
# [[102, 33, 474, 737], [295, 347, 382, 639], [86, 58, 564, 628]]
# [[102, 33, 474, 737], [295, 347, 382, 639], [83, 63, 564, 637], [86, 58, 564, 628]]

# %%
# Assuming `image` is a PIL Image, convert it to display with matplotlib
image_np = np.array(image)

fig, ax = plt.subplots(1)
ax.imshow(image_np)

# Color map for different classes
color_map = plt.get_cmap('tab20b')

for box in new_bbox:
    xmin, ymin, xmax, ymax = box
    
    # Create a Rectangle patch
    rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, linewidth=1,
                             edgecolor=color_map(label % 20), facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)
    ax.text(xmin, ymin, f'{label}: {score:.2f}', color='white', 
            bbox=dict(facecolor='red', alpha=0.5))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\JALAL\OneDrive\Bureau\BENet\CorrectionEmotiC\Emotic_Correction\Max_people.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Assuming `image` is a PIL Image, convert it to display with matplotlib
#       <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> image_np = np.array(image)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> fig, ax = plt.subplots(1)
#       <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> ax.imshow(image_np)
#       <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> # Color map for different classes
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Model prestation

# %%
def iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1g, y1g, x2g, y2g = box2
    # determine the coordinates of the intersection rectangle
    xA = max(x1, x1g)
    yA = max(y1, y1g)
    xB = min(x2, x2g)
    yB = min(y2, y2g)
    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    # compute the area of both the prediction and ground-truth
    # rectangles
    boxAArea = (x2 - x1 + 1) * (y2 - y1 + 1)
    boxBArea = (x2g - x1g + 1) * (y2g - y1g + 1)
    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = interArea / float(boxAArea + boxBArea - interArea)
    # return the intersection over union value
    return iou

def get_iou(bbox1, bbox2, thresh, new_annots = []):
    iou_score = iou(bbox1, bbox2)
    if iou_score > thresh:
        new_annots.append(bbox1)
        #new_annots.append(bbox2)
    else:
        new_annots.append(bbox1)
        new_annots.append(bbox2)
    return new_annots

def model_results(img):
   
    image_processor = AutoImageProcessor.from_pretrained("facebook/detr-resnet-50")
    model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50")
    inputs = image_processor(images=img, return_tensors="pt")
    outputs = model(**inputs)

    results = image_processor.post_process_object_detection(outputs, threshold=0.95, target_sizes=torch.tensor([img.size[::-1]]))[0]

    person_scores = []
    person_labels = []
    person_boxes = []

    for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
        if model.config.id2label[label.item()] == 'person':
            person_labels.append(label)
            # Ensure the box is detached before any manipulation
            person_boxes.append(box.detach())
            person_scores.append(score.item())

    # Sorting the results by score
    sorted_indices = np.argsort(person_scores)[::-1]

    sorted_person_labels = [person_labels[i] for i in sorted_indices]
    sorted_person_boxes = [person_boxes[i] for i in sorted_indices]
    sorted_person_scores = [person_scores[i] for i in sorted_indices]

    # Calculating area for sorting requires detaching and converting to numpy, which is already done for boxes
    areas = [box[2].item() * box[3].item() for box in sorted_person_boxes]
    sorted_indices = np.argsort(areas)[::-1]

    sorted_person_labels = [sorted_person_labels[i] for i in sorted_indices]
    sorted_person_boxes = [sorted_person_boxes[i] for i in sorted_indices]
    sorted_person_scores = [sorted_person_scores[i] for i in sorted_indices]

    sorted_results = {
        "scores": sorted_person_scores,
        "labels": sorted_person_labels,
        "boxes": sorted_person_boxes
    }

    bboxes = [[int(x.item()) for x in bbox] for bbox in sorted_results["boxes"]]
    bboxes = bboxes[:25]
    
    last_bboxes = []
    for box1 in bboxes:
        for box2 in bboxes:
            get_iou(box1, box2, 0.8, last_bboxes)
    last_bboxes = remove_duplicates(last_bboxes)
    
    return last_bboxes

# %%
url = "EMOTIC (1)\EMOTIC\PAMI\emotic\/framesdb\images\\frame_0clx8zgnq849lkze.jpg"
url = url.replace("\\", "/")

image = Image.open(url)

bboxes = model_results(image)

image_np = np.array(image)

fig, ax = plt.subplots(1)
ax.imshow(image_np)

# Color map for different classes
color_map = plt.get_cmap('tab20b')

for box in bboxes:
    xmin, ymin, xmax, ymax = box
    
    # Create a Rectangle patch
    rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, linewidth=1,
                             edgecolor=color_map(label % 20), facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)
    ax.text(xmin, ymin, f'{label}: {score:.2f}', color='white', 
            bbox=dict(facecolor='red', alpha=0.5))

plt.show()
bboxes
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [[311, 1896, 692, 2849],
#  [3182, 1806, 3433, 2741],
#  [3593, 1817, 3753, 2364],
#  [1624, 1812, 2012, 3058],
#  [2095, 1832, 2328, 2456],
#  [2574, 1763, 2810, 2636],
#  [912, 1821, 1181, 2658]]

# %%
import json 

train = json.load(open('newestEMOTIC_train_x1y1x2y2.json'))
train
# Out:
# {'images': [{'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000562243.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 640,
#    'id': 0,
#    'coco_ids': {'image_id': 562243, 'annotations_id': 448867}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000288841.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 1,
#    'coco_ids': {'image_id': 288841, 'annotations_id': 1750456}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000558171.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 2,
#    'coco_ids': {'image_id': 558171, 'annotations_id': 467799}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000369575.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 480,
#    'id': 3,
#    'coco_ids': {'image_id': 369575, 'annotations_id': 192459}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000213009.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 333,
#    'width': 500,
#    'id': 4,
#    'coco_ids': {'image_id': 213009, 'annotations_id': 1243960}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000462955.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 478,
#    'width': 640,
#    'id': 5,
#    'coco_ids': {'image_id': 462955, 'annotations_id': 1212177}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000168683.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 6,
#    'coco_ids': {'image_id': 168683, 'annotations_id': 486631}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000186198.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 429,
#    'width': 640,
#    'id': 7,
#    'coco_ids': {'image_id': 186198, 'annotations_id': 442474}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000006590.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 8,
#    'coco_ids': {'image_id': 6590, 'annotations_id': 218375}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000144608.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 500,
#    'width': 350,
#    'id': 9,
#    'coco_ids': {'image_id': 144608, 'annotations_id': 216135}},
#   {'database': 'EMOTIC',
#    'file_name': 'ebpsbjqzfhd7efh00i.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 471,
#    'width': 623,
#    'id': 10,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000547457.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 11,
#    'coco_ids': {'image_id': 547457, 'annotations_id': 424485}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000122997.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 12,
#    'coco_ids': {'image_id': 122997, 'annotations_id': 558850}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_k245twaqc30i5imc.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 334,
#    'width': 500,
#    'id': 13,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_dkwhvgj0m40g01gs.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 641,
#    'width': 634,
#    'id': 14,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000179164.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 15,
#    'coco_ids': {'image_id': 179164, 'annotations_id': 201513}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000121006.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 455,
#    'width': 640,
#    'id': 16,
#    'coco_ids': {'image_id': 121006, 'annotations_id': 475911}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_fjgek3oeqc8r0e3o.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 499,
#    'width': 749,
#    'id': 17,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000140322.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 512,
#    'width': 640,
#    'id': 18,
#    'coco_ids': {'image_id': 140322, 'annotations_id': 460502}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000497759.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 500,
#    'width': 500,
#    'id': 19,
#    'coco_ids': {'image_id': 497759, 'annotations_id': 486921}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000001966.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 20,
#    'coco_ids': {'image_id': 1966, 'annotations_id': 484353}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000326320.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 21,
#    'coco_ids': {'image_id': 326320, 'annotations_id': 519731}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_kuxvwgw2wheq7szc.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 378,
#    'width': 570,
#    'id': 22,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_95x221h7yj814qxc.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 1944,
#    'width': 2592,
#    'id': 23,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000253959.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 588,
#    'id': 24,
#    'coco_ids': {'image_id': 253959, 'annotations_id': 197346}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000022683.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 25,
#    'coco_ids': {'image_id': 22683, 'annotations_id': 1745563}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000094268.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 26,
#    'coco_ids': {'image_id': 94268, 'annotations_id': 530216}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000231589.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 27,
#    'coco_ids': {'image_id': 231589, 'annotations_id': 436689}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000423647.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 28,
#    'coco_ids': {'image_id': 423647, 'annotations_id': 1230877}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000411109.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 456,
#    'width': 640,
#    'id': 29,
#    'coco_ids': {'image_id': 411109, 'annotations_id': 1709353}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000461715.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 30,
#    'coco_ids': {'image_id': 461715, 'annotations_id': 190424}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000055276.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 31,
#    'coco_ids': {'image_id': 55276, 'annotations_id': 188093}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000568202.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 612,
#    'width': 612,
#    'id': 32,
#    'coco_ids': {'image_id': 568202, 'annotations_id': 187967}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_erwzk3npaleubsqm.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 311,
#    'width': 450,
#    'id': 33,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000088609.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 34,
#    'coco_ids': {'image_id': 88609, 'annotations_id': 496645}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000054277.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 35,
#    'coco_ids': {'image_id': 54277, 'annotations_id': 450589}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000549216.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 36,
#    'coco_ids': {'image_id': 549216, 'annotations_id': 213241}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000551481.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 640,
#    'id': 37,
#    'coco_ids': {'image_id': 551481, 'annotations_id': 440303}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000528657.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 427,
#    'id': 38,
#    'coco_ids': {'image_id': 528657, 'annotations_id': 504662}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_b1v3bzyq8s4ucvy1.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 3651,
#    'width': 5477,
#    'id': 39,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000552054.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 460,
#    'width': 640,
#    'id': 40,
#    'coco_ids': {'image_id': 552054, 'annotations_id': 234850}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000379034.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 41,
#    'coco_ids': {'image_id': 379034, 'annotations_id': 1279497}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000390644.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 424,
#    'width': 640,
#    'id': 42,
#    'coco_ids': {'image_id': 390644, 'annotations_id': 511291}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000107239.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 43,
#    'coco_ids': {'image_id': 107239, 'annotations_id': 1238257}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000322698.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 44,
#    'coco_ids': {'image_id': 322698, 'annotations_id': 206938}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000508538.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 45,
#    'coco_ids': {'image_id': 508538, 'annotations_id': 1306422}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000563727.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 46,
#    'coco_ids': {'image_id': 563727, 'annotations_id': 520386}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000182785.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 428,
#    'width': 640,
#    'id': 47,
#    'coco_ids': {'image_id': 182785, 'annotations_id': 211331}},
#   {'database': 'EMOTIC',
#    'file_name': 'gs84txnh5el02zkbp9.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 225,
#    'width': 225,
#    'id': 48,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000408190.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 640,
#    'id': 49,
#    'coco_ids': {'image_id': 408190, 'annotations_id': 427526}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_aztc78d4kjclxv9e.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 400,
#    'width': 600,
#    'id': 50,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_7nseu023ccmqaj3p.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 499,
#    'width': 799,
#    'id': 51,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000432683.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 52,
#    'coco_ids': {'image_id': 432683, 'annotations_id': 2150796}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000233526.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 361,
#    'width': 640,
#    'id': 53,
#    'coco_ids': {'image_id': 233526, 'annotations_id': 220754}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000137029.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 471,
#    'width': 640,
#    'id': 54,
#    'coco_ids': {'image_id': 137029, 'annotations_id': 2151703}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000274108.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 55,
#    'coco_ids': {'image_id': 274108, 'annotations_id': 480884}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000149755.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 56,
#    'coco_ids': {'image_id': 149755, 'annotations_id': 187412}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000159225.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 57,
#    'coco_ids': {'image_id': 159225, 'annotations_id': 1219304}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000298949.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 612,
#    'width': 612,
#    'id': 58,
#    'coco_ids': {'image_id': 298949, 'annotations_id': 1255493}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_j44zhny87dief9zp.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 500,
#    'width': 500,
#    'id': 59,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_kpokdxsxymvz4qk3.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 500,
#    'width': 960,
#    'id': 60,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000524651.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 61,
#    'coco_ids': {'image_id': 524651, 'annotations_id': 453246}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_08cmg83x4uc6vay4.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 2448,
#    'width': 3264,
#    'id': 62,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_3jwi6nrvfphi4lp6.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 433,
#    'width': 730,
#    'id': 63,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000053608.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 452,
#    'width': 640,
#    'id': 64,
#    'coco_ids': {'image_id': 53608, 'annotations_id': 192984}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000274642.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 427,
#    'id': 65,
#    'coco_ids': {'image_id': 274642, 'annotations_id': 1203841}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_hzo04gqf487tm689.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 556,
#    'width': 370,
#    'id': 66,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000482172.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 427,
#    'id': 67,
#    'coco_ids': {'image_id': 482172, 'annotations_id': 473518}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000576031.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 68,
#    'coco_ids': {'image_id': 576031, 'annotations_id': 445741}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000014103.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 69,
#    'coco_ids': {'image_id': 14103, 'annotations_id': 1730799}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_8bcjgl84a80cguy5.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 457,
#    'width': 675,
#    'id': 70,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_bwnq9ntic9dpamg2.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 354,
#    'width': 500,
#    'id': 71,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': '78tk87458zwsmxaoi7.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 258,
#    'width': 460,
#    'id': 72,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_6290od7o4jvss70n.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 320,
#    'width': 320,
#    'id': 73,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000498702.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 74,
#    'coco_ids': {'image_id': 498702, 'annotations_id': 465319}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000261879.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 75,
#    'coco_ids': {'image_id': 261879, 'annotations_id': 421995}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000167028.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 76,
#    'coco_ids': {'image_id': 167028, 'annotations_id': 1201172}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_gq8umfw35sg36nlq.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 418,
#    'width': 634,
#    'id': 77,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'h705hnfsvdwf6mh2xw.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 300,
#    'width': 300,
#    'id': 78,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000282027.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 79,
#    'coco_ids': {'image_id': 282027, 'annotations_id': 487082}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000396793.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 80,
#    'coco_ids': {'image_id': 396793, 'annotations_id': 427459}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_88u3mzsacaic5583.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 3630,
#    'width': 2586,
#    'id': 81,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000252375.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 443,
#    'id': 82,
#    'coco_ids': {'image_id': 252375, 'annotations_id': 1201829}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_hdepjixs67t3l4zo.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 316,
#    'width': 420,
#    'id': 83,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000483078.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 430,
#    'width': 640,
#    'id': 84,
#    'coco_ids': {'image_id': 483078, 'annotations_id': 476086}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000110392.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 85,
#    'coco_ids': {'image_id': 110392, 'annotations_id': 454899}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000509626.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 457,
#    'width': 640,
#    'id': 86,
#    'coco_ids': {'image_id': 509626, 'annotations_id': 1248632}},
#   {'database': 'EMOTIC',
#    'file_name': 'ab3l4riuiqrc4ivkqk.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 400,
#    'width': 300,
#    'id': 87,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': '4le1bbiky5djx0iuln.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 720,
#    'width': 1280,
#    'id': 88,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000102225.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 89,
#    'coco_ids': {'image_id': 102225, 'annotations_id': 1233826}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000533291.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 90,
#    'coco_ids': {'image_id': 533291, 'annotations_id': 478876}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_482f0lsguoiv0sk6.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 305,
#    'width': 400,
#    'id': 91,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000377160.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 92,
#    'coco_ids': {'image_id': 377160, 'annotations_id': 471506}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000510791.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 428,
#    'width': 640,
#    'id': 93,
#    'coco_ids': {'image_id': 510791, 'annotations_id': 452956}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000252801.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 94,
#    'coco_ids': {'image_id': 252801, 'annotations_id': 183120}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000108758.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 95,
#    'coco_ids': {'image_id': 108758, 'annotations_id': 2017340}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000107072.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 458,
#    'width': 640,
#    'id': 96,
#    'coco_ids': {'image_id': 107072, 'annotations_id': 1314389}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_ddghjgrf7k9jei5j.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 800,
#    'width': 533,
#    'id': 97,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_7qztqnocqk4d67lc.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 733,
#    'width': 1100,
#    'id': 98,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_hkvjon62ft6acgnx.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 381,
#    'width': 364,
#    'id': 99,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000571264.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 100,
#    'coco_ids': {'image_id': 571264, 'annotations_id': 217633}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000565387.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 594,
#    'id': 101,
#    'coco_ids': {'image_id': 565387, 'annotations_id': 205644}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000385280.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 579,
#    'width': 640,
#    'id': 102,
#    'coco_ids': {'image_id': 385280, 'annotations_id': 484328}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000331832.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 103,
#    'coco_ids': {'image_id': 331832, 'annotations_id': 476699}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_6x5lpc7dh3yvrnc3.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 512,
#    'width': 760,
#    'id': 104,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_jsnriwfd0ffphs5g.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 746,
#    'width': 1059,
#    'id': 105,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_63mtckpdjfc0y9q8.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 2508,
#    'width': 4000,
#    'id': 106,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000202476.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 107,
#    'coco_ids': {'image_id': 202476, 'annotations_id': 467419}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000269588.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 635,
#    'width': 640,
#    'id': 108,
#    'coco_ids': {'image_id': 269588, 'annotations_id': 188649}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_98zn80gxar4u0kzg.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 350,
#    'width': 620,
#    'id': 109,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000106596.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 458,
#    'width': 640,
#    'id': 110,
#    'coco_ids': {'image_id': 106596, 'annotations_id': 433191}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000385744.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 111,
#    'coco_ids': {'image_id': 385744, 'annotations_id': 466675}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000147012.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 112,
#    'coco_ids': {'image_id': 147012, 'annotations_id': 1222616}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000334220.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 113,
#    'coco_ids': {'image_id': 334220, 'annotations_id': 1706739}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000167397.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 114,
#    'coco_ids': {'image_id': 167397, 'annotations_id': 1734603}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000221625.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 320,
#    'width': 640,
#    'id': 115,
#    'coco_ids': {'image_id': 221625, 'annotations_id': 421246}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_0v2clxpnah9oj514.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 455,
#    'width': 634,
#    'id': 116,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000160480.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 117,
#    'coco_ids': {'image_id': 160480, 'annotations_id': 451261}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000560391.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 118,
#    'coco_ids': {'image_id': 560391, 'annotations_id': 469497}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000028642.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 429,
#    'width': 640,
#    'id': 119,
#    'coco_ids': {'image_id': 28642, 'annotations_id': 2019090}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000178283.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 120,
#    'coco_ids': {'image_id': 178283, 'annotations_id': 438561}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_1cnsgmoppetoruv9.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 600,
#    'width': 900,
#    'id': 121,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000336858.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 315,
#    'width': 640,
#    'id': 122,
#    'coco_ids': {'image_id': 336858, 'annotations_id': 443620}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_hqxrmmcc6c2zqzr4.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 320,
#    'width': 450,
#    'id': 123,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000431405.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 124,
#    'coco_ids': {'image_id': 431405, 'annotations_id': 441113}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_ek3zcwpt9ed6j6gm.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 1200,
#    'width': 1600,
#    'id': 125,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000091159.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 126,
#    'coco_ids': {'image_id': 91159, 'annotations_id': 462782}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000361895.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 127,
#    'coco_ids': {'image_id': 361895, 'annotations_id': 445345}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_4b7yta6mg9sm2x6n.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 619,
#    'width': 1100,
#    'id': 128,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000389772.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 129,
#    'coco_ids': {'image_id': 389772, 'annotations_id': 1725798}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000025461.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 457,
#    'width': 640,
#    'id': 130,
#    'coco_ids': {'image_id': 25461, 'annotations_id': 204650}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000024571.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 131,
#    'coco_ids': {'image_id': 24571, 'annotations_id': 448560}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_fvot32utqi78m926.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 1071,
#    'width': 1600,
#    'id': 132,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000254011.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 514,
#    'width': 640,
#    'id': 133,
#    'coco_ids': {'image_id': 254011, 'annotations_id': 448927}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000563349.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 427,
#    'id': 134,
#    'coco_ids': {'image_id': 563349, 'annotations_id': 438675}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000213135.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 135,
#    'coco_ids': {'image_id': 213135, 'annotations_id': 188053}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000256276.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 136,
#    'coco_ids': {'image_id': 256276, 'annotations_id': 432525}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_6npxf90s9ozbfo99.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 798,
#    'width': 1200,
#    'id': 137,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_gfeivpuiazkxf29e.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 361,
#    'width': 379,
#    'id': 138,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_jbtqq5ahai9ylby3.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 3376,
#    'width': 4576,
#    'id': 139,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000394058.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 140,
#    'coco_ids': {'image_id': 394058, 'annotations_id': 467881}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000006692.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 640,
#    'id': 141,
#    'coco_ids': {'image_id': 6692, 'annotations_id': 189089}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000288223.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 142,
#    'coco_ids': {'image_id': 288223, 'annotations_id': 526176}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000360548.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 143,
#    'coco_ids': {'image_id': 360548, 'annotations_id': 212570}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000047801.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 612,
#    'width': 612,
#    'id': 144,
#    'coco_ids': {'image_id': 47801, 'annotations_id': 449043}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000002842.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 145,
#    'coco_ids': {'image_id': 2842, 'annotations_id': 1258542}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000199865.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 146,
#    'coco_ids': {'image_id': 199865, 'annotations_id': 458856}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_2m658fp3xgkeqkug.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 1067,
#    'width': 1600,
#    'id': 147,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000441828.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 148,
#    'coco_ids': {'image_id': 441828, 'annotations_id': 517627}},
#   {'database': 'EMOTIC',
#    'file_name': '03tzxn73art6yidfhe.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 480,
#    'width': 720,
#    'id': 149,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000087604.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 375,
#    'width': 500,
#    'id': 150,
#    'coco_ids': {'image_id': 87604, 'annotations_id': 485051}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000042312.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 515,
#    'width': 640,
#    'id': 151,
#    'coco_ids': {'image_id': 42312, 'annotations_id': 443048}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000156763.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 463,
#    'width': 640,
#    'id': 152,
#    'coco_ids': {'image_id': 156763, 'annotations_id': 521068}},
#   {'database': 'EMOTIC',
#    'file_name': 'sun_ajjqvlkgojhqxjal.jpg',
#    'folder': 'ade20k/images',
#    'name': 'ade20k',
#    'height': 1228,
#    'width': 1818,
#    'id': 153,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000162177.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 480,
#    'id': 154,
#    'coco_ids': {'image_id': 162177, 'annotations_id': 448120}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000509403.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 155,
#    'coco_ids': {'image_id': 509403, 'annotations_id': 524685}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000367519.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 236,
#    'width': 640,
#    'id': 156,
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000202906.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 500,
#    'width': 375,
#    'id': 157,
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_c9ctv7ctm2dnic4v.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 1521,
#    'width': 1600,
#    'id': 158,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000230061.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 159,
#    'coco_ids': {'image_id': 230061, 'annotations_id': 216393}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000163435.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 360,
#    'width': 640,
#    'id': 160,
#    'coco_ids': {'image_id': 163435, 'annotations_id': 427266}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_k43u0wqy98p0ihaw.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 2592,
#    'width': 3888,
#    'id': 161,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_8add2r7r1w3oj417.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 579,
#    'width': 1276,
#    'id': 162,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000030299.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 163,
#    'coco_ids': {'image_id': 30299, 'annotations_id': 514405}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000181929.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 164,
#    'coco_ids': {'image_id': 181929, 'annotations_id': 518725}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000071223.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 165,
#    'coco_ids': {'image_id': 71223, 'annotations_id': 427164}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000248403.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 500,
#    'width': 375,
#    'id': 166,
#    'coco_ids': {'image_id': 248403, 'annotations_id': 430974}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000360271.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 480,
#    'id': 167,
#    'coco_ids': {'image_id': 360271, 'annotations_id': 476607}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000470053.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 168,
#    'coco_ids': {'image_id': 470053, 'annotations_id': 451338}},
#   {'database': 'EMOTIC',
#    'file_name': '9jhdi4c8zh2fruuuz8.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 289,
#    'width': 600,
#    'id': 169,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000055516.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 480,
#    'id': 170,
#    'coco_ids': {'image_id': 55516, 'annotations_id': 428470}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000219935.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 171,
#    'coco_ids': {'image_id': 219935, 'annotations_id': 1299910}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000319521.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 539,
#    'width': 640,
#    'id': 172,
#    'coco_ids': {'image_id': 319521, 'annotations_id': 540972}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_4pnnwfq2nvd0l7sk.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 325,
#    'width': 344,
#    'id': 173,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000347263.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 174,
#    'coco_ids': {'image_id': 347263, 'annotations_id': 560266}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000129510.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 431,
#    'width': 640,
#    'id': 175,
#    'coco_ids': {'image_id': 129510, 'annotations_id': 201574}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000505818.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 176,
#    'coco_ids': {'image_id': 505818, 'annotations_id': 202792}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000512854.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 177,
#    'coco_ids': {'image_id': 512854, 'annotations_id': 208319}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000415551.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 436,
#    'width': 640,
#    'id': 178,
#    'coco_ids': {'image_id': 415551, 'annotations_id': 524418}},
#   {'database': 'EMOTIC',
#    'file_name': 'edknfl4d7l58nt06sm.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 226,
#    'width': 340,
#    'id': 179,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000178411.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 472,
#    'width': 640,
#    'id': 180,
#    'coco_ids': {'image_id': 178411, 'annotations_id': 476340}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_a7xhjxzcp8nhw69p.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 2448,
#    'width': 3264,
#    'id': 181,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000222681.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 182,
#    'coco_ids': {'image_id': 222681, 'annotations_id': 510773}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000485090.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 183,
#    'coco_ids': {'image_id': 485090, 'annotations_id': 422221}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_fq5auwuqb7gh7kn6.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 450,
#    'width': 600,
#    'id': 184,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000097924.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 400,
#    'width': 600,
#    'id': 185,
#    'coco_ids': {'image_id': 97924, 'annotations_id': 203611}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000074345.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 427,
#    'id': 186,
#    'coco_ids': {'image_id': 74345, 'annotations_id': 473084}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000439678.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 187,
#    'coco_ids': {'image_id': 439678, 'annotations_id': 499996}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000468993.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 188,
#    'coco_ids': {'image_id': 468993, 'annotations_id': 442471}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000246280.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 432,
#    'width': 640,
#    'id': 189,
#    'coco_ids': {'image_id': 246280, 'annotations_id': 481561}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000298031.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 190,
#    'coco_ids': {'image_id': 298031, 'annotations_id': 471206}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000148911.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 639,
#    'id': 191,
#    'coco_ids': {'image_id': 148911, 'annotations_id': 441338}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000169863.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 192,
#    'coco_ids': {'image_id': 169863, 'annotations_id': 448067}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000426839.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 488,
#    'width': 640,
#    'id': 193,
#    'coco_ids': {'image_id': 426839, 'annotations_id': 456757}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000567082.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 429,
#    'width': 640,
#    'id': 194,
#    'coco_ids': {'image_id': 567082, 'annotations_id': 1259356}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000147568.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 480,
#    'width': 640,
#    'id': 195,
#    'coco_ids': {'image_id': 147568, 'annotations_id': 433762}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_3oyfqqmeecsjb728.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 400,
#    'width': 620,
#    'id': 196,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000075783.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 197,
#    'coco_ids': {'image_id': 75783, 'annotations_id': 465218}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000458057.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 426,
#    'width': 640,
#    'id': 198,
#    'coco_ids': {'image_id': 458057, 'annotations_id': 216073}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_gko26fo2wzz06i1r.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 501,
#    'width': 700,
#    'id': 199,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000552247.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 425,
#    'width': 640,
#    'id': 200,
#    'coco_ids': {'image_id': 552247, 'annotations_id': 534145}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000221521.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 334,
#    'width': 500,
#    'id': 201,
#    'coco_ids': {'image_id': 221521, 'annotations_id': 2152265}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000457168.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 449,
#    'width': 640,
#    'id': 202,
#    'coco_ids': {'image_id': 457168, 'annotations_id': 2161607}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000271906.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 429,
#    'width': 640,
#    'id': 203,
#    'coco_ids': {'image_id': 271906, 'annotations_id': 1264210}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000552985.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 601,
#    'width': 640,
#    'id': 204,
#    'coco_ids': {'image_id': 552985, 'annotations_id': 475193}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000186246.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 640,
#    'width': 480,
#    'id': 205,
#    'coco_ids': {'image_id': 186246, 'annotations_id': 496365}},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000481931.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 458,
#    'width': 640,
#    'id': 206,
#    'coco_ids': {'image_id': 481931, 'annotations_id': 473666}},
#   {'database': 'EMOTIC',
#    'file_name': 'frame_8z9jb1ci5zo2x7tt.jpg',
#    'folder': 'framesdb/images',
#    'name': 'framesdb',
#    'height': 613,
#    'width': 900,
#    'id': 207,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_train2014_000000412720.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
#    'height': 427,
#    'width': 640,
#    'id': 208,
#    'coco_ids': {'image_id': 412720, 'annotations_id': 211439}},
#   {'database': 'EMOTIC',
#    'file_name': '6h85d8d0rrvntefpkq.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 480,
#    'width': 852,
#    'id': 209,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': '007eear5kx5qhbzewz.jpg',
#    'folder': 'emodb_small/images',
#    'name': 'emodb_small',
#    'height': 400,
#    'width': 580,
#    'id': 210,
#    'coco_ids': []},
#   {'database': 'EMOTIC',
#    'file_name': 'COCO_val2014_000000553443.jpg',
#    'folder': 'mscoco/images',
#    'name': 'mscoco',
# ...
#   {'image_id': 152,
#    'id': 947,
#    'category_id': 1,
#    'bbox': [223, 31, 380, 451],
#    'coco_ids': {'image_id': 156763, 'annotations_id': 521068},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 8, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 153,
#    'id': 948,
#    'category_id': 1,
#    'bbox': [1196, 116, 1808, 1219],
#    'coco_ids': [],
#    'annotations_categories': ['Engagement'],
#    'annotations_continuous': {'valence': 5, 'arousal': 3, 'dominance': 6},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 154,
#    'id': 949,
#    'category_id': 1,
#    'bbox': [102, 160, 203, 434],
#    'coco_ids': {'image_id': 162177, 'annotations_id': 448120},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 7, 'arousal': 5, 'dominance': 6},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 154,
#    'id': 950,
#    'category_id': 1,
#    'bbox': [0, 161, 12, 218],
#    'coco_ids': {'image_id': 162177, 'annotations_id': 448120},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 7, 'arousal': 5, 'dominance': 6},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 154,
#    'id': 951,
#    'category_id': 1,
#    'bbox': [207, 156, 314, 436],
#    'coco_ids': {'image_id': 162177, 'annotations_id': 448120},
#    'annotations_categories': ['Pleasure'],
#    'annotations_continuous': {'valence': 7, 'arousal': 5, 'dominance': 6},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 154,
#    'id': 952,
#    'category_id': 1,
#    'bbox': [0, 161, 12, 218],
#    'coco_ids': {'image_id': 162177, 'annotations_id': 448120},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 7, 'arousal': 3, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 154,
#    'id': 953,
#    'category_id': 1,
#    'bbox': [103, 155, 207, 434],
#    'coco_ids': {'image_id': 162177, 'annotations_id': 448120},
#    'annotations_categories': ['Disquietment', 'Fatigue'],
#    'annotations_continuous': {'valence': 7, 'arousal': 3, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 155,
#    'id': 954,
#    'category_id': 1,
#    'bbox': [33, 163, 92, 294],
#    'coco_ids': {'image_id': 509403, 'annotations_id': 524685},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 9, 'dominance': 9},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 155,
#    'id': 955,
#    'category_id': 1,
#    'bbox': [359, 59, 479, 373],
#    'coco_ids': {'image_id': 509403, 'annotations_id': 524685},
#    'annotations_categories': ['Anticipation', 'Esteem', 'Excitement'],
#    'annotations_continuous': {'valence': 6, 'arousal': 9, 'dominance': 9},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 155,
#    'id': 956,
#    'category_id': 1,
#    'bbox': [174, 128, 214, 232],
#    'coco_ids': {'image_id': 509403, 'annotations_id': 524685},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 9, 'dominance': 9},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 957,
#    'category_id': 1,
#    'bbox': [603, 39, 639, 212],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 958,
#    'category_id': 1,
#    'bbox': [63, 53, 78, 78],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 959,
#    'category_id': 1,
#    'bbox': [490, 28, 529, 151],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 960,
#    'category_id': 1,
#    'bbox': [393, 55, 458, 180],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 961,
#    'category_id': 1,
#    'bbox': [321, 57, 380, 180],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 962,
#    'category_id': 1,
#    'bbox': [260, 34, 328, 179],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 963,
#    'category_id': 1,
#    'bbox': [0, 21, 59, 204],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 964,
#    'category_id': 1,
#    'bbox': [373, 58, 394, 91],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 156,
#    'id': 965,
#    'category_id': 1,
#    'bbox': [51, 48, 128, 214],
#    'coco_ids': {'image_id': 367519, 'annotations_id': 1327347},
#    'annotations_categories': ['Confidence', 'Excitement'],
#    'annotations_continuous': {'valence': 8, 'arousal': 2, 'dominance': 8},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 966,
#    'category_id': 1,
#    'bbox': [26, 68, 56, 152],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 967,
#    'category_id': 1,
#    'bbox': [27, 129, 80, 200],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 968,
#    'category_id': 1,
#    'bbox': [214, 140, 259, 235],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 969,
#    'category_id': 1,
#    'bbox': [44, 163, 111, 306],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 970,
#    'category_id': 1,
#    'bbox': [213, 167, 336, 400],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 971,
#    'category_id': 1,
#    'bbox': [111, 55, 149, 139],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 157,
#    'id': 972,
#    'category_id': 1,
#    'bbox': [110, 151, 229, 294],
#    'coco_ids': {'image_id': 202906, 'annotations_id': 1242730},
#    'annotations_categories': ['Disconnection'],
#    'annotations_continuous': {'valence': 8, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 158,
#    'id': 973,
#    'category_id': 1,
#    'bbox': [0, 5, 683, 1502],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 974,
#    'category_id': 1,
#    'bbox': [478, 0, 737, 472],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 975,
#    'category_id': 1,
#    'bbox': [1020, 378, 1598, 1250],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 976,
#    'category_id': 1,
#    'bbox': [944, 0, 1434, 752],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 977,
#    'category_id': 1,
#    'bbox': [566, 9, 1103, 1028],
#    'coco_ids': [],
#    'annotations_categories': ['Engagement', 'Esteem'],
#    'annotations_continuous': {'valence': 5, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 978,
#    'category_id': 1,
#    'bbox': [1067, 372, 1585, 1153],
#    'coco_ids': [],
#    'annotations_categories': ['Happiness'],
#    'annotations_continuous': {'valence': 5, 'arousal': 4, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 979,
#    'category_id': 1,
#    'bbox': [0, 5, 683, 1502],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 4, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 980,
#    'category_id': 1,
#    'bbox': [478, 0, 737, 472],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 4, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 981,
#    'category_id': 1,
#    'bbox': [571, 54, 1129, 1006],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 4, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 982,
#    'category_id': 1,
#    'bbox': [1020, 378, 1598, 1250],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 4, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 983,
#    'category_id': 1,
#    'bbox': [944, 0, 1434, 752],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 4, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Kid'},
#   {'image_id': 158,
#    'id': 984,
#    'category_id': 1,
#    'bbox': [31, 1, 732, 1347],
#    'coco_ids': [],
#    'annotations_categories': ['Affection', 'Confidence', 'Engagement'],
#    'annotations_continuous': {'valence': 5, 'arousal': 2, 'dominance': 9},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 158,
#    'id': 985,
#    'category_id': 1,
#    'bbox': [478, 0, 737, 472],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 2, 'dominance': 9},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 158,
#    'id': 986,
#    'category_id': 1,
#    'bbox': [571, 54, 1129, 1006],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 2, 'dominance': 9},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 158,
#    'id': 987,
#    'category_id': 1,
#    'bbox': [1020, 378, 1598, 1250],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 2, 'dominance': 9},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 158,
#    'id': 988,
#    'category_id': 1,
#    'bbox': [944, 0, 1434, 752],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 5, 'arousal': 2, 'dominance': 9},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 159,
#    'id': 989,
#    'category_id': 1,
#    'bbox': [161, 197, 274, 479],
#    'coco_ids': {'image_id': 230061, 'annotations_id': 216393},
#    'annotations_categories': ['Engagement'],
#    'annotations_continuous': {'valence': 5, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 160,
#    'id': 990,
#    'category_id': 1,
#    'bbox': [385, 77, 453, 294],
#    'coco_ids': {'image_id': 163435, 'annotations_id': 427266},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 160,
#    'id': 991,
#    'category_id': 1,
#    'bbox': [463, 102, 507, 223],
#    'coco_ids': {'image_id': 163435, 'annotations_id': 427266},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 160,
#    'id': 992,
#    'category_id': 1,
#    'bbox': [300, 76, 465, 326],
#    'coco_ids': {'image_id': 163435, 'annotations_id': 427266},
#    'annotations_categories': ['Confidence',
#     'Engagement',
#     'Excitement',
#     'Happiness'],
#    'annotations_continuous': {'valence': 6, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 160,
#    'id': 993,
#    'category_id': 1,
#    'bbox': [524, 100, 582, 259],
#    'coco_ids': {'image_id': 163435, 'annotations_id': 427266},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 160,
#    'id': 994,
#    'category_id': 1,
#    'bbox': [500, 135, 520, 193],
#    'coco_ids': {'image_id': 163435, 'annotations_id': 427266},
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 6, 'dominance': 6},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 161,
#    'id': 995,
#    'category_id': 1,
#    'bbox': [13, 859, 1557, 2517],
#    'coco_ids': [],
#    'annotations_categories': ['Happiness'],
#    'annotations_continuous': {'valence': 6, 'arousal': 3, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 161,
#    'id': 996,
#    'category_id': 1,
#    'bbox': [10, 640, 3107, 2554],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 3, 'dominance': 3},
#    'gender': 'Male',
#    'age': 'Adult'},
#   {'image_id': 161,
#    'id': 997,
#    'category_id': 1,
#    'bbox': [1000, 770, 3407, 2576],
#    'coco_ids': [],
#    'annotations_categories': ['Excitement', 'Happiness', 'Peace'],
#    'annotations_continuous': {'valence': 7, 'arousal': 3, 'dominance': 4},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 161,
#    'id': 998,
#    'category_id': 1,
#    'bbox': [10, 640, 3107, 2554],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 7, 'arousal': 3, 'dominance': 4},
#    'gender': 'Female',
#    'age': 'Adult'},
#   {'image_id': 162,
#    'id': 999,
#    'category_id': 1,
#    'bbox': [66, 213, 214, 573],
#    'coco_ids': [],
#    'annotations_categories': None,
#    'annotations_continuous': {'valence': 6, 'arousal': 4, 'dominance': 7},
#    'gender': 'Male',
#    'age': 'Adult'},
#   ...],
#  'categories': [{'supercategory': 'person',
#    'id': 1,
#    'name': 'person',
#    'keypoints': ['nose',
#     'left_eye',
#     'right_eye',
#     'left_ear',
#     'right_ear',
#     'left_shoulder',
#     'right_shoulder',
#     'left_elbow',
#     'right_elbow',
#     'left_wrist',
#     'right_wrist',
#     'left_hip',
#     'right_hip',
#     'left_knee',
#     'right_knee',
#     'left_ankle',
#     'right_ankle'],
#    'skeleton': [[16, 14],
#     [14, 12],
#     [17, 15],
#     [15, 13],
#     [12, 13],
#     [6, 12],
#     [7, 13],
#     [6, 7],
#     [6, 8],
#     [7, 9],
#     [8, 10],
#     [9, 11],
#     [2, 3],
#     [1, 2],
#     [1, 3],
#     [2, 4],
#     [3, 5],
#     [4, 6],
#     [5, 7]]}]}

# %%
img = train["images"][20]
img
# Out:
# {'database': 'EMOTIC',
#  'file_name': 'COCO_train2014_000000001966.jpg',
#  'folder': 'mscoco/images',
#  'name': 'mscoco',
#  'height': 480,
#  'width': 640,
#  'id': 20,
#  'coco_ids': {'image_id': 1966, 'annotations_id': 484353}}

# %%
img_ann0 = train["annotations"][63]["bbox"]
img_ann = train["annotations"][64]["bbox"]
img_ann1 = train["annotations"][65]["bbox"]

# %%
bboxes = []
bboxes.append(img_ann0)
bboxes.append(img_ann1)
bboxes.append(img_ann)

# %%
import matplotlib.pyplot as plt 
import matplotlib.patches as patches

url = "EMOTIC (1)\EMOTIC\PAMI\emotic\/mscoco\images/COCO_train2014_000000001966.jpg"
url = url.replace("\\", "/")

image = Image.open(url)


image_np = np.array(image)

fig, ax = plt.subplots(1)
ax.imshow(image_np)

# Color map for different classes
color_map = plt.get_cmap('tab20b')

for box in bboxes:
    xmin, ymin, xmax, ymax = box
    
    # Create a Rectangle patch
    rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, linewidth=1,
                             edgecolor=color_map(label % 20), facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)
    #ax.text(xmin, ymin, f'{label}: {score:.2f}', color='white', 
            #bbox=dict(facecolor='red', alpha=0.5))

plt.show()
bboxes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\JALAL\OneDrive\Bureau\BENet\CorrectionEmotiC\Emotic_Correction\Max_people.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#X21sZmlsZQ%3D%3D?line=18'>19</a> xmin, ymin, xmax, ymax = box
#      <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#X21sZmlsZQ%3D%3D?line=20'>21</a> # Create a Rectangle patch
#      <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#X21sZmlsZQ%3D%3D?line=21'>22</a> rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, linewidth=1,
# ---> <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#X21sZmlsZQ%3D%3D?line=22'>23</a>                          edgecolor=color_map(label % 20), facecolor='none')
#      <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#X21sZmlsZQ%3D%3D?line=24'>25</a> # Add the patch to the Axes
#      <a href='vscode-notebook-cell:/c%3A/Users/JALAL/OneDrive/Bureau/BENet/CorrectionEmotiC/Emotic_Correction/Max_people.ipynb#X21sZmlsZQ%3D%3D?line=25'>26</a> ax.add_patch(rect)
#
# NameError: name 'label' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
